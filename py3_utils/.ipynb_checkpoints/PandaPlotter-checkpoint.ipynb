# %%
from PandaPlotter import PandaPlotter
args = dict(px="..",file='pyorbit_twiss_sizes_ekin.dat', x='position', y='betaX', y2="betaY")
p = PandaPlotter(args)
p.data_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4705 entries, 0 to 4704
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Node          4705 non-null   object
#  1   position      4705 non-null   float64
#  2   alphaX        4705 non-null   float64
#  3   betaX         4705 non-null   float64
#  4   emittX        4705 non-null   float64
#  5   normEmittX    4705 non-null   float64
#  6   alphaY        4705 non-null   float64
#  7   betaY         4705 non-null   float64
#  8   emittY        4705 non-null   float64
#  9   normEmittY    4705 non-null   float64
#  10  alphaZ        4705 non-null   float64
#  11  betaZ         4705 non-null   float64
#  12  emittZ        4705 non-null   float64
#  13  emittZphiMeV  4705 non-null   float64
#  14  sizeX         4705 non-null   float64
#  15  sizeY         4705 non-null   float64
#  16  sizeZ_deg     4705 non-null   float64
# ...

# %%
p.do_plot(args)
# Out:
# ...
# plotting ordinates "['betaX', 'betaY']" against abscissa "position"
# ...

# %%
args = dict(x='position', y='emittX', y2="normEmittX")
p.do_plot(args)
# Out:
# ...
# plotting ordinates "['emittX', 'normEmittX']" against abscissa "position"
# ...
